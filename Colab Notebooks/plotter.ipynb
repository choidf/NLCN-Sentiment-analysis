# %%
import csv
def metrics_listing2(list):
    epochs=[]
    train_loss_values = []
    eval_loss_values = []
    eval_accuracy_values = []
    eval_f1_values = []
    for i in range(0, 10, 2): 
        epochs.append(list[i]['epoch'])
        train_loss_values.append(list[i]['loss'])

    for j in range(1, 11, 2): 
        eval_loss_values.append(list[j]['eval_loss'])
        eval_accuracy_values.append(list[j]['eval_accuracy'])
        eval_f1_values.append(list[j]['eval_f1'])
    metrics_dict = {
        'epochs': epochs,
        'train_loss': train_loss_values,
        'eval_loss': eval_loss_values,
        'eval_acc': eval_accuracy_values,
        'eval_f1': eval_f1_values
    }
    return metrics_dict

# %%
bert_log = [{'loss': 0.0535, 'learning_rate': 1.6000000000000003e-05, 'epoch': 1.0, 'step': 1407}, {'eval_loss': 0.4188264012336731, 'eval_accuracy': 0.9224, 'eval_f1': 0.9221508828250402, 'eval_runtime': 87.4177, 'eval_samples_per_second': 28.598, 'eval_steps_per_second': 1.796, 'epoch': 1.0, 'step': 1407}, {'loss': 0.0324, 'learning_rate': 1.2e-05, 'epoch': 2.0, 'step': 2814}, {'eval_loss': 0.43820664286613464, 'eval_accuracy': 0.928, 'eval_f1': 0.9287974683544304, 'eval_runtime': 87.5184, 'eval_samples_per_second': 28.565, 'eval_steps_per_second': 1.794, 'epoch': 2.0, 'step': 2814}, {'loss': 0.0201, 'learning_rate': 8.000000000000001e-06, 'epoch': 3.0, 'step': 4221}, {'eval_loss': 0.4541590213775635, 'eval_accuracy': 0.928, 'eval_f1': 0.9308224442736357, 'eval_runtime': 87.2695, 'eval_samples_per_second': 28.647, 'eval_steps_per_second': 1.799, 'epoch': 3.0, 'step': 4221}, {'loss': 0.0202, 'learning_rate': 4.000000000000001e-06, 'epoch': 4.0, 'step': 5628}, {'eval_loss': 0.4746588468551636, 'eval_accuracy': 0.9296, 'eval_f1': 0.9320987654320987, 'eval_runtime': 86.8316, 'eval_samples_per_second': 28.791, 'eval_steps_per_second': 1.808, 'epoch': 4.0, 'step': 5628}, {'loss': 0.0057, 'learning_rate': 0.0, 'epoch': 5.0, 'step': 7035}, {'eval_loss': 0.5128756761550903, 'eval_accuracy': 0.9308, 'eval_f1': 0.9325009754194303, 'eval_runtime': 87.0066, 'eval_samples_per_second': 28.733, 'eval_steps_per_second': 1.804, 'epoch': 5.0, 'step': 7035}, {'train_runtime': 10960.5142, 'train_samples_per_second': 10.264, 'train_steps_per_second': 0.642, 'total_flos': 2.929411890392352e+16, 'train_loss': 0.026391833236900388, 'epoch': 5.0, 'step': 7035}]
distilbert_log = [{'loss': 0.2724, 'learning_rate': 1.6000000000000003e-05, 'epoch': 1.0, 'step': 1407}, {'eval_loss': 0.22071291506290436, 'eval_accuracy': 0.9192, 'eval_f1': 0.9209083790133124, 'eval_runtime': 42.441, 'eval_samples_per_second': 58.905, 'eval_steps_per_second': 3.699, 'epoch': 1.0, 'step': 1407}, {'loss': 0.1629, 'learning_rate': 1.2e-05, 'epoch': 2.0, 'step': 2814}, {'eval_loss': 0.25577354431152344, 'eval_accuracy': 0.9192, 'eval_f1': 0.919457735247209, 'eval_runtime': 42.2951, 'eval_samples_per_second': 59.108, 'eval_steps_per_second': 3.712, 'epoch': 2.0, 'step': 2814}, {'loss': 0.0947, 'learning_rate': 8.000000000000001e-06, 'epoch': 3.0, 'step': 4221}, {'eval_loss': 0.3341638743877411, 'eval_accuracy': 0.9248, 'eval_f1': 0.9266770670826833, 'eval_runtime': 42.2294, 'eval_samples_per_second': 59.2, 'eval_steps_per_second': 3.718, 'epoch': 3.0, 'step': 4221}, {'loss': 0.0542, 'learning_rate': 4.000000000000001e-06, 'epoch': 4.0, 'step': 5628}, {'eval_loss': 0.3523482382297516, 'eval_accuracy': 0.926, 'eval_f1': 0.9278189621537262, 'eval_runtime': 42.2252, 'eval_samples_per_second': 59.206, 'eval_steps_per_second': 3.718, 'epoch': 4.0, 'step': 5628}, {'loss': 0.0325, 'learning_rate': 0.0, 'epoch': 5.0, 'step': 7035}, {'eval_loss': 0.37905800342559814, 'eval_accuracy': 0.926, 'eval_f1': 0.9273655280722418, 'eval_runtime': 42.1985, 'eval_samples_per_second': 59.244, 'eval_steps_per_second': 3.721, 'epoch': 5.0, 'step': 7035}, {'train_runtime': 5240.6688, 'train_samples_per_second': 21.467, 'train_steps_per_second': 1.342, 'total_flos': 1.4748584858256192e+16, 'train_loss': 0.12333626221830996, 'epoch': 5.0, 'step': 7035}]
roberta_log = [{'loss': 0.2475, 'learning_rate': 1.6000000000000003e-05, 'epoch': 1.0, 'step': 1407}, {'eval_loss': 0.22871315479278564, 'eval_accuracy': 0.936, 'eval_f1': 0.938319198149576, 'eval_runtime': 91.1398, 'eval_samples_per_second': 27.43, 'eval_steps_per_second': 1.723, 'epoch': 1.0, 'step': 1407}, {'loss': 0.1528, 'learning_rate': 1.2e-05, 'epoch': 2.0, 'step': 2814}, {'eval_loss': 0.2354215830564499, 'eval_accuracy': 0.9328, 'eval_f1': 0.9318734793187348, 'eval_runtime': 90.9178, 'eval_samples_per_second': 27.497, 'eval_steps_per_second': 1.727, 'epoch': 2.0, 'step': 2814}, {'loss': 0.0888, 'learning_rate': 8.000000000000001e-06, 'epoch': 3.0, 'step': 4221}, {'eval_loss': 0.2754134237766266, 'eval_accuracy': 0.9432, 'eval_f1': 0.9452160493827161, 'eval_runtime': 90.6095, 'eval_samples_per_second': 27.591, 'eval_steps_per_second': 1.733, 'epoch': 3.0, 'step': 4221}, {'loss': 0.0476, 'learning_rate': 4.000000000000001e-06, 'epoch': 4.0, 'step': 5628}, {'eval_loss': 0.29616469144821167, 'eval_accuracy': 0.9464, 'eval_f1': 0.947533281127643, 'eval_runtime': 90.6561, 'eval_samples_per_second': 27.577, 'eval_steps_per_second': 1.732, 'epoch': 4.0, 'step': 5628}, {'loss': 0.0275, 'learning_rate': 0.0, 'epoch': 5.0, 'step': 7035}, {'eval_loss': 0.3320925831794739, 'eval_accuracy': 0.9476, 'eval_f1': 0.9488481062085123, 'eval_runtime': 90.5058, 'eval_samples_per_second': 27.623, 'eval_steps_per_second': 1.735, 'epoch': 5.0, 'step': 7035}, {'train_runtime': 11764.4959, 'train_samples_per_second': 9.563, 'train_steps_per_second': 0.598, 'total_flos': 2.919741531330312e+16, 'train_loss': 0.11283670518952392, 'epoch': 5.0, 'step': 7035}]

# %%
from matplotlib.pylab import plt
from numpy import arange

# Generate a sequence of integers to represent the epoch numbers
bert_metrics = metrics_listing2(bert_log)
distilbert_metrics = metrics_listing2(distilbert_log)
roberta = metrics_listing2(roberta_log)

epochs = range(1, 6)

# Plot and label the training and validation loss values
plt.plot(epochs, bert_metrics['eval_f1'], label='BERT Eval F1 Score')
plt.plot(epochs, distilbert_metrics['eval_f1'], label='distilBERT Eval F1 Score')
plt.plot(epochs, roberta['eval_f1'], label='RoBERTa Eval F1 Score')
 
# # Add in a title and axes labels
plt.title('Eval F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
 
# # Set the tick locations
plt.xticks(arange(1, 6, 1))

# # Display the plot
plt.legend(loc='best')
plt.show()
